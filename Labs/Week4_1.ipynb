# %% [markdown]
# <a href="https://colab.research.google.com/github/EmmanuelChinkaka/PUS2022_EChinkaka/blob/main/Labs/Week4_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
#Load the data
data = pd.read_csv('https://raw.githubusercontent.com/fedhere/PUS2022_FBianco/main/classdemo/times.txt', header=None)

data

#mean = data.mean()
#std = data.std()

mean
std

mu = 34
sigma = 2.5

# %%
z = (mu - data.mean())/(sigma/np.sqrt(len(data)))
z
# Out:
# 0   -1.864647
# dtype: float64

# %%
data.describe()
# Out:
#                 0
# count  100.000000
# mean    34.466162
# std      7.137280
# min     16.527267
# 25%     30.020542
# 50%     34.693057
# 75%     39.603456
# max     48.749877
